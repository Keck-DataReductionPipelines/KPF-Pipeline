# %% [markdown]
# # All Time Series Database Keywords

# %%
from modules.quicklook.src.analyze_time_series import AnalyzeTimeSeries
import pandas as pd
pd.set_option('display.max_rows', None)
db_path = 'kpf_ts.db'
myTS = AnalyzeTimeSeries(db_path=db_path)
myTS.db.print_metadata_table()
# Out:
# INFO: Starting AnalyzeTimeSeries
# INFO: Starting KPF_TSDB
# INFO: Jupyter Notebook environment detected.
# INFO: Base data directory: /data/L0
# INFO: Backend: sqlite
# INFO: Path of database file: /code/KPF-Pipeline/docs/source/tutorials/kpf_ts.db
# INFO: Metadata table exists.
# INFO: Metadata table read.
# INFO: Data tables exist.
# Base Keywords:
# --------------------------------------------------------------------------------------------------------------------------------
# Keyword                             Datatype  Indexed Units     Description
# --------------------------------------------------------------------------------------------------------------------------------
# D2_filename                         string    Yes               Full path to 2D file
# D2_header_read_time                 string    Yes               Last modification of 2D file
# DEC_deg                             float     Yes     deg       declination (e.g., 188.736249)
# L0_filename                         string    Yes               Full path to L0 file
# L0_header_read_time                 string    Yes               Last modification of L0 file
# L1_filename                         string    Yes               Full path to L1 file
# L1_header_read_time                 string    Yes               Last modification of L1 file
# L2_filename                         string    Yes               Full path to L2 file
# L2_header_read_time                 string    Yes               Last modification of L2 file
# ObsID                               string    Yes               Observation ID (e.g., KP.20240101.12345.67)
# RA_deg                              float     Yes     deg       right ascension (e.g., 5.272777)
# Source                              string    Yes               Source type (e.g., 'Star' or 'Flat')
# datecode                            string    Yes               8-digit date code (e.g., 20240101)
#
# L0 PRIMARY Header:
# --------------------------------------------------------------------------------------------------------------------------------
# Keyword                             Datatype  Indexed Units     Description
# --------------------------------------------------------------------------------------------------------------------------------
# 2MASSID                             string    No                2MASS Target name from kpfconfig
# 2MASSMAG                            float     No      mag       2MASS J band magnitude
# AGITSTA                             string    No                Agigator state (Running/Stopped)
# AIRMASS                             float     Yes               Airmass of target
# AZ                                  float     No      deg       Telescope azimuth
# CAL-OBJ                             string    Yes               Cal fiber source
# CA_HK                               string    No                Ca HK camera found (Yes/No)
# DATE-BEG                            datetime  Yes               Start of exposure (shutter open time)
# DATE-END                            datetime  Yes               End of exposure (shutter close time)
# DATE-MID                            datetime  Yes               Halfway point of the exposure (unweighted)
# DCSNAME                             string    No                DCS Target name - may not make any sense
# DEC                                 string    No      deg       Declination
# EL                                  float     No      deg       Telescope elevation
# ELAPSED                             float     No      sec       Actual exposure time
# EMDATE-B                            datetime  No                Exposure meter DATE-BEG
# EMDATE-E                            datetime  No                Exposure meter DATE-END
# EQUINOX                             float     No                DCS Equinox
# ETAV1C1T                            float     No      C         Etalon housing temp (Vescent 1 Channel 1)
# ETAV1C2T                            float     No      C         Etalon inner side shield temp (Vescent 1 Channel 2)
# ETAV1C3T                            float     No      C         Etalon inner bottom lid temp (Vescent 1 Channel 3)
# ETAV1C4T                            float     No      C         Etalon outer etalon chamber temp (Vescent 1 Channel 4)
# ETAV2C3T                            float     No      C         Etalon inner top lid temp (Vescent 2 Channel 3)
# EXPMETER                            string    No                Exposure meter camera found (Yes/No)
# EXPTIME                             float     Yes     sec       Requested exposure time
# FFFB                                string    No                Flat field fiber on (Yes/No)
# FIUMODE                             string    Yes               FIU operating mode - Observing = on-sky
# FRAMENO                             int       No                Frame number
# FULLTARG                            string    No                Full Target name from kpfconfig
# GAIAID                              string    Yes               GAIA Target name from kpfconfig
# GAIAMAG                             float     No      mag       GAIA G band magnitude
# GRDATE-B                            datetime  No                Green camera DATE-BEG
# GRDATE-E                            datetime  No                Green camera DATE-END
# GREEN                               string    No                Green camera found (Yes/No)
# GUIDE                               string    No                Guide camera found (Yes/No)
# HA                                  string    Yes     hr        Hour angle
# IMTYPE                              string    Yes               Image type
# MJD-OBS                             float     No      days      Modified Julian day of the observation start
# OBJECT                              string    Yes               Object name
# OCTAGON                             string    No                Calibration octagon source
# PBRB                                float     No      Watts     Last Broadband power meter measurement
# PBRBT                               string    No                Time of last Broadband power measurement
# PETAL                               float     No      Watts     Last Etalon power meter measurement
# PETALT                              string    No                Time of last Etalon power measurement
# PLFC                                float     No      Watts     Last LFC power meter measurement
# PLFCT                               string    No                Time of last LFC power measurement
# PROGNAME                            string    No                Program name
# PSOL                                float     No      Watts     Last SoCal-CalFib power meter measurement
# PSOLT                               string    No                Time of last SoCal-CalFib power measurement
# PTHAU                               float     No      Watts     Last ThAr Gold power meter measurement
# PTHAUT                              string    No                Time of last ThAr Gold power measurement
# PTHDAY                              float     No      Watts     Last ThAr Daily power meter measurement
# PTHDAYT                             string    No                Time of last ThAr Daily power measurement
# PUAU                                float     No      Watts     Last UNe Gold power meter measurement
# PUAUT                               string    No                Time of last UNe Gold power measurement
# PUDAY                               float     No      Watts     Last UNe Daily power meter measurement
# PUDAYT                              string    No                Time of last UNe Daily power measurement
# RA                                  string    No      hr        Right ascension
# RDDATE-B                            datetime  No                Red camera DATE-BEG
# RDDATE-E                            datetime  No                Red camera DATE-END
# RED                                 string    No                Red camera found (Yes/No)
# SBELEV                              float     No      deg       Bottom shutter elevation
# SBVIGNE                             bool      No                Bottom shutter vignetting
# SCI-OBJ                             string    Yes               Science fiber source
# SKY-OBJ                             string    Yes               Sky fiber source
# STELEV                              float     No      deg       Top shutter elevation
# STVIGNE                             bool      No                Top shutter vignetting
# TARGDEC                             string    No      deg       DCS Target Dec
# TARGEPOC                            float     No                DCS Target epoch
# TARGEQUI                            float     No                DCS Target equinox
# TARGFRAM                            string    No                Target frame
# TARGNAME                            string    No                KPF Target name
# TARGPLAX                            float     No      as        Target parallax
# TARGPMDC                            float     No      as/yr     Target proper motion dec
# TARGPMRA                            float     No      s/yr      Target proper motion ra
# TARGRA                              string    No      hr        DCS Target RA
# TARGRADV                            float     No      km/s      Target radial velocity
# TARGTEFF                            float     No      K         Target effective temp
# TARGWAVE                            float     No      microns   Target Wavelength
# THRSBIN                             float     No      nm        Threshold wavelength
# THRSHLD                             float     No      counts    Threshold level
# TIMEERR                             string    No                NTP time server response
# TOTCNTS                             string    No      counts    Total EM counts in WAVEBINS
# TOTCORR                             string    No      counts    Total EM counts (corrected) in WAVEBINS
# USTHRSH                             string    No                Was exposure meter thresholding used? (Yes/No)
# VIGNETTE                            bool      No                Dome vignetting
# WAVEBNS                             string    No      nm        Wavelengths of EM bins (string of four vals)
#
# 2D PRIMARY Header:
# --------------------------------------------------------------------------------------------------------------------------------
# Keyword                             Datatype  Indexed Units     Description
# --------------------------------------------------------------------------------------------------------------------------------
# AGEBIAS                             float     No      days      BIASFILE age
# AGEDARK                             float     No      days      DARKFILE age
# AGEFLAT                             float     No      days      FLATFILE age
# AGITOK                              bool      Yes               QC: Agitator running with speed above minimum
# BIASDIR                             string    No                Directory for BIASDIR
# BIASFILE                            string    No                Master bias file used (except for bias exposures)
# CAHKPR2D                            bool      Yes               QC: 2D CaHK data present
# DARKDIR                             string    No                Directory for DARKDIR
# DARKFILE                            string    No                Master dark file used (except for dark exposures)
# DATAPR2D                            bool      Yes               QC: 2D red and green data present
# DATAPRL0                            bool      Yes               QC: L0 data products present with non-zero array sizes
# DRPHSH2D                            string    Yes               Git commit hash version of KPF-Pipeline used to make 2D
# DRPTAG2D                            string    Yes               Git version number of KPF-Pipeline used to make 2D
# EMNEG                               bool      Yes               QC: Exp Meter not negative flux
# EMSAT                               bool      Yes               QC: Exp Meter not saturated
# FLATDIR                             string    No                Directory for FLATDIR
# FLATFILE                            string    No                Master flat file used (except for flat exposures)
# FLXAMP1G                            float     No      e-/hr     Dark curr, Green amp region 1 = [3700:4000,700:1000]
# FLXAMP1R                            float     No      e-/hr     Dark curr, Red amp region 1 = [3700:4000,700:1000]
# FLXAMP2G                            float     No      e-/hr     Dark curr, Green amp region 2 = [3700:4000,3080:3380]
# FLXAMP2R                            float     No      e-/hr     Dark curr, Red amp region 2 = [3700:4000,3080:3380]
# FLXCOLLG                            float     No      e-/hr     Dark curr, Green coll-side region = [3700:4000,700:1000]
# FLXCOLLR                            float     No      e-/hr     Dark curr, Red coll-side region = [3700:4000,700:1000]
# FLXECHG                             float     No      e-/hr     Dark curr, Green ech-side region = [3700:4000,700:1000]
# FLXECHR                             float     No      e-/hr     Dark curr, Red ech-side region = [3700:4000,700:1000]
# FLXREG1G                            float     No      e-/hr     Dark curr, Green region 1 = [1690:1990,1690:1990]
# FLXREG1R                            float     No      e-/hr     Dark curr, Red region 1 = [1690:1990,1690:1990]
# FLXREG2G                            float     No      e-/hr     Dark curr, Green region 2 = [1690:1990,2090:2390]
# FLXREG2R                            float     No      e-/hr     Dark curr, Red region 2 = [1690:1990,2090:2390]
# FLXREG3G                            float     No      e-/hr     Dark curr, Green region 3 = [2090:2390,1690:1990]
# FLXREG3R                            float     No      e-/hr     Dark curr, Red region 3 = [2090:2390,1690:1990]
# FLXREG4G                            float     No      e-/hr     Dark curr, Green region 4 = [2090:2390,2090:2390]
# FLXREG4R                            float     No      e-/hr     Dark curr, Red region 4 = [2090:2390,2090:2390]
# FLXREG5G                            float     No      e-/hr     Dark curr, Green region 5 = [80:380,3080:3380]
# FLXREG5R                            float     No      e-/hr     Dark curr, Red region 5 = [80:380,3080:3380]
# FLXREG6G                            float     No      e-/hr     Dark curr, Green region 6 = [1690:1990,1690:1990]
# FLXREG6R                            float     No      e-/hr     Dark curr, Red region 6 = [1690:1990,1690:1990]
# GDRRRMS                             float     No      mas       r-coordinate RMS guiding error
# GDRSEEJZ                            float     No      arcsec    Seeing in J+Z-band from Moffat func fit
# GDRSEEV                             float     No      arcsec    Scaled seeing in V-band from J+Z-band
# GDRXBIAS                            float     No      mas       x-coordinate bias guiding error
# GDRXRMS                             float     No      mas       x-coordinate RMS guiding error
# GDRYBIAS                            float     No      mas       y-coordinate bias guiding error
# GDRYRMS                             float     No      mas       y-coordinate RMS guiding error
# GOODREAD                            bool      Yes               QC: Texp not consistent with CCD readout error
# GREENTRT                            float     No      sec       Green read time
# GUIDGOOD                            bool      Yes               QC: Guider RMS and bias within 50 mas RMS
# KPFERA                              string    Yes               The era during which the observation was made, e.g. '2.0'
# KWRDPRL0                            bool      Yes               QC: L0 expected keywords present
# LFC2DFOK                            bool      Yes               QC: LFC flux meets threshold of 4000 counts
# LOWBIAS                             bool      Yes               QC: 2D bias flux not low
# LOWDARK                             bool      Yes               QC: 2D dark flux not low
# MOONSEP                             float     No      deg       Separation between Moon and target star
# NOTJUNK                             bool      Yes               Not in the list of junk files check
# NTPGOOD                             bool      Yes               QC: NTP time within 100 ms
# OLDBIAS                             bool      Yes               QC: Master bias within 5 days of this obs
# OLDDARK                             bool      Yes               QC: Master dark within 5 days of this obs
# OLDFLAT                             bool      Yes               QC: Master flat within 5 days of this obs
# POS2DSNR                            bool      Yes               QC: 2D Red/Green data/var^0.5 not significantly negative
# READSPED                            string    No                Categorization of CCD read speed ('regular' or 'fast')
# REDTRT                              float     No      sec       Red read time
# RNGREEN1                            float     No      e-        Read noise for GREEN_AMP1 (first amp region on Green)
# RNGREEN2                            float     No      e-        Read noise for GREEN_AMP2 (second amp region on Green)
# RNNGGR1                             float     No                Non-Gaussian read noise GREEN1, 0.8*stddev/mad of overscan
# RNNGGR2                             float     No                Non-Gaussian read noise GREEN2, 0.8*stddev/mad of overscan
# RNNGGR3                             float     No                Non-Gaussian read noise GREEN3, 0.8*stddev/mad of overscan
# RNNGGR4                             float     No                Non-Gaussian read noise GREEN4, 0.8*stddev/mad of overscan
# RNNGRD1                             float     No                Non-Gaussian read noise RED1, 0.8*stddev/mad of overscan
# RNNGRD2                             float     No                Non-Gaussian read noise RED2, 0.8*stddev/mad of overscan
# RNNGRD3                             float     No                Non-Gaussian read noise RED3, 0.8*stddev/mad of overscan
# RNNGRD4                             float     No                Non-Gaussian read noise RED4, 0.8*stddev/mad of overscan
# RNRED1                              float     No      e-        Read noise for RED_AMP1 (first amp region on Red)
# RNRED2                              float     No      e-        Read noise for RED_AMP2 (second amp region on Red)
# SUNALT                              float     No      deg       Altitude of Sun; negative = below horizon
# TARGPLAU                            bool      Yes               QC: TARG kwds present with plausible values
# TIMCHKL0                            bool      Yes               QC: Consistent times in L0 file
# XDSPDYG1                            float     No      pixels    Green cross-dispersion offset compared to master reference
# XDSPDYG2                            float     No      pixels    Green cross-dispersion offset compared to reference in era
# XDSPDYR1                            float     No      pixels    Red cross-dispersion offset compared to master reference
# XDSPDYR2                            float     No      pixels    Red cross-dispersion offset compared to reference in era
# XDSPSYG1                            float     No      pixels    Uncertainty in XDSPDYG1
# XDSPSYG2                            float     No      pixels    Uncertainty in XDSPDYG2
# XDSPSYR1                            float     No      pixels    Uncertainty in XDSPDYR1
# XDSPSYR2                            float     No      pixels    Uncertainty in XDSPDYR2
#
# L1 PRIMARY Header:
# --------------------------------------------------------------------------------------------------------------------------------
# Keyword                             Datatype  Indexed Units     Description
# --------------------------------------------------------------------------------------------------------------------------------
# AGELAMP                             float     No      days      Smooth lamp file approx age
# AGETRAC                             float     No      days      Trace file approx age
# AGEWLS                              float     No      days      WLSFILE approx age
# AGEWLS2                             float     No      days      WLSFILE2 approx age
# CAHKPRL1                            bool      Yes               QC: CaHK data present in L1 with expected shape
# DATAPRL1                            bool      Yes               QC: L1 red and green data present
# DRPHSHL1                            string    Yes               Git commit hash version of KPF-Pipeline used to make L1
# DRPTAGL1                            string    Yes               Git version number of KPF-Pipeline used to make L1
# EMSCCT45                            float     No      ADU       cumulative EM counts in SCI in 445-551 nm
# EMSCCT48                            float     No      ADU       cumulative EM counts in SCI in 445-870 nm
# EMSCCT56                            float     No      ADU       cumulative EM counts in SCI in 551-658 nm
# EMSCCT67                            float     No      ADU       cumulative EM counts in SCI in 658-764 nm
# EMSCCT78                            float     No      ADU       cumulative EM counts in SCI in 764-870 nm
# EMSKCT45                            float     No      ADU       cumulative EM counts in SKY in 445-551 nm
# EMSKCT48                            float     No      ADU       cumulative EM counts in SKY in 445-870 nm
# EMSKCT56                            float     No      ADU       cumulative EM counts in SKY in 551-658 nm
# EMSKCT67                            float     No      ADU       cumulative EM counts in SKY in 658-764 nm
# EMSKCT78                            float     No      ADU       cumulative EM counts in SKY in 764-870 nm
# ETALGC0                             int       No                Min Green CAL order with good Etalon lines
# ETALGC1                             int       No                Max Green CAL order with good Etalon lines
# ETALGK0                             int       No                Min Green SKY order with good Etalon lines
# ETALGK1                             int       No                Max Green SKY order with good Etalon lines
# ETALGS0                             int       No                Min Green SCI order with good Etalon lines
# ETALGS1                             int       No                Max Green SCI order with good Etalon lines
# ETALINES                            bool      Yes               QC: Number and dist of Etalon lines sufficient
# ETALRC0                             int       No                Min Red CAL order with good Etalon lines
# ETALRC1                             int       No                Max Red CAL order with good Etalon lines
# ETALRK0                             int       No                Min Red SKY order with good Etalon lines
# ETALRK1                             int       No                Max Red SKY order with good Etalon lines
# ETALRS0                             int       No                Min Red SCI order with good Etalon lines
# ETALRS1                             int       No                Max Red SCI order with good Etalon lines
# FLATSNR                             bool      Yes               QC: SNR of flat >min and <max
# FR12M452                            float     No                median(SCI1/SCI2) flux ratio near 452 nm
# FR12M548                            float     No                median(SCI1/SCI2) flux ratio near 548 nm
# FR12M652                            float     No                median(SCI1/SCI2) flux ratio near 652 nm
# FR12M747                            float     No                median(SCI1/SCI2) flux ratio near 747 nm
# FR12M852                            float     No                median(SCI1/SCI2) flux ratio near 852 nm
# FR12U452                            float     No                uncertainty on FR12M452
# FR12U548                            float     No                uncertainty on FR12M548
# FR12U652                            float     No                uncertainty on FR12M652
# FR12U747                            float     No                uncertainty on FR12M747
# FR12U852                            float     No                uncertainty on FR12M852
# FR32M452                            float     No                median(SCI3/SCI2) flux ratio near 452 nm
# FR32M548                            float     No                median(SCI3/SCI2) flux ratio near 548 nm
# FR32M652                            float     No                median(SCI3/SCI2) flux ratio near 652 nm
# FR32M747                            float     No                median(SCI3/SCI2) flux ratio near 747 nm
# FR32M852                            float     No                median(SCI3/SCI2) flux ratio near 852 nm
# FR32U452                            float     No                uncertainty on FR32M452
# FR32U548                            float     No                uncertainty on FR32M548
# FR32U652                            float     No                uncertainty on FR32M652
# FR32U747                            float     No                uncertainty on FR32M747
# FR32U852                            float     No                uncertainty on FR32M852
# FR452652                            float     No                Peak flux ratio between orders (452nm/652nm)
# FR548652                            float     No                Peak flux ratio between orders (548nm/652nm)
# FR747652                            float     No                Peak flux ratio between orders (747nm/652nm)
# FR852652                            float     No                Peak flux ratio between orders (852nm/652nm)
# FRC2M452                            float     No                median(CAL/SCI2) flux ratio near 452 nm
# FRC2M548                            float     No                median(CAL/SCI2) flux ratio near 548 nm
# FRC2M652                            float     No                median(CAL/SCI2) flux ratio near 652 nm
# FRC2M747                            float     No                median(CAL/SCI2) flux ratio near 747 nm
# FRC2M852                            float     No                median(CAL/SCI2) flux ratio near 852 nm
# FRC2U452                            float     No                uncertainty on FRC2M452
# FRC2U548                            float     No                uncertainty on FRC2M548
# FRC2U652                            float     No                uncertainty on FRC2M652
# FRC2U747                            float     No                uncertainty on FRC2M747
# FRC2U852                            float     No                uncertainty on FRC2M852
# FRS2M452                            float     No                median(SKY/SCI2) flux ratio near 452 nm
# FRS2M548                            float     No                median(SKY/SCI2) flux ratio near 548 nm
# FRS2M652                            float     No                median(SKY/SCI2) flux ratio near 652 nm
# FRS2M747                            float     No                median(SKY/SCI2) flux ratio near 747 nm
# FRS2M852                            float     No                median(SKY/SCI2) flux ratio near 852 nm
# FRS2U452                            float     No                uncertainty on FRS2M452
# FRS2U548                            float     No                uncertainty on FRS2M548
# FRS2U652                            float     No                uncertainty on FRS2M652
# FRS2U747                            float     No                uncertainty on FRS2M747
# FRS2U852                            float     No                uncertainty on FRS2M852
# LFCLGC0                             int       No                Min Green CAL order with good LFC lines
# LFCLGC1                             int       No                Max Green CAL order with good LFC lines
# LFCLGK0                             int       No                Min Green SKY order with good LFC lines
# LFCLGK1                             int       No                Max Green SKY order with good LFC lines
# LFCLGS0                             int       No                Min Green SCI order with good LFC lines
# LFCLGS1                             int       No                Max Green SCI order with good LFC lines
# LFCLINES                            bool      Yes               QC: Number and dist of LFC lines sufficient
# LFCLRC0                             int       No                Min Red CAL order with good LFC lines
# LFCLRC1                             int       No                Max Red CAL order with good LFC lines
# LFCLRK0                             int       No                Min Red SKY order with good LFC lines
# LFCLRK1                             int       No                Max Red SKY order with good LFC lines
# LFCLRS0                             int       No                Min Red SCI order with good LFC lines
# LFCLRS1                             int       No                Max Red SCI order with good LFC lines
# LFCSAT                              bool      Yes               QC: L1 LFC spectrum not saturated
# MEDWGC00                            float     No      pixels    median(WLS-ref) [pix], Green CAL order 00
# MEDWGC01                            float     No      pixels    median(WLS-ref) [pix], Green CAL order 01
# MEDWGC02                            float     No      pixels    median(WLS-ref) [pix], Green CAL order 02
# MEDWGC03                            float     No      pixels    median(WLS-ref) [pix], Green CAL order 03
# MEDWGC04                            float     No      pixels    median(WLS-ref) [pix], Green CAL order 04
# MEDWGC05                            float     No      pixels    median(WLS-ref) [pix], Green CAL order 05
# MEDWGC06                            float     No      pixels    median(WLS-ref) [pix], Green CAL order 06
# MEDWGC07                            float     No      pixels    median(WLS-ref) [pix], Green CAL order 07
# MEDWGC08                            float     No      pixels    median(WLS-ref) [pix], Green CAL order 08
# MEDWGC09                            float     No      pixels    median(WLS-ref) [pix], Green CAL order 09
# MEDWGC10                            float     No      pixels    median(WLS-ref) [pix], Green CAL order 10
# MEDWGC11                            float     No      pixels    median(WLS-ref) [pix], Green CAL order 11
# MEDWGC12                            float     No      pixels    median(WLS-ref) [pix], Green CAL order 12
# MEDWGC13                            float     No      pixels    median(WLS-ref) [pix], Green CAL order 13
# MEDWGC14                            float     No      pixels    median(WLS-ref) [pix], Green CAL order 14
# MEDWGC15                            float     No      pixels    median(WLS-ref) [pix], Green CAL order 15
# MEDWGC16                            float     No      pixels    median(WLS-ref) [pix], Green CAL order 16
# MEDWGC17                            float     No      pixels    median(WLS-ref) [pix], Green CAL order 17
# MEDWGC18                            float     No      pixels    median(WLS-ref) [pix], Green CAL order 18
# MEDWGC19                            float     No      pixels    median(WLS-ref) [pix], Green CAL order 19
# MEDWGC20                            float     No      pixels    median(WLS-ref) [pix], Green CAL order 20
# MEDWGC21                            float     No      pixels    median(WLS-ref) [pix], Green CAL order 21
# MEDWGC22                            float     No      pixels    median(WLS-ref) [pix], Green CAL order 22
# MEDWGC23                            float     No      pixels    median(WLS-ref) [pix], Green CAL order 23
# MEDWGC24                            float     No      pixels    median(WLS-ref) [pix], Green CAL order 24
# MEDWGC25                            float     No      pixels    median(WLS-ref) [pix], Green CAL order 25
# MEDWGC26                            float     No      pixels    median(WLS-ref) [pix], Green CAL order 26
# MEDWGC27                            float     No      pixels    median(WLS-ref) [pix], Green CAL order 27
# MEDWGC28                            float     No      pixels    median(WLS-ref) [pix], Green CAL order 28
# MEDWGC29                            float     No      pixels    median(WLS-ref) [pix], Green CAL order 29
# MEDWGC30                            float     No      pixels    median(WLS-ref) [pix], Green CAL order 30
# MEDWGC31                            float     No      pixels    median(WLS-ref) [pix], Green CAL order 31
# MEDWGC32                            float     No      pixels    median(WLS-ref) [pix], Green CAL order 32
# MEDWGC33                            float     No      pixels    median(WLS-ref) [pix], Green CAL order 33
# MEDWGC34                            float     No      pixels    median(WLS-ref) [pix], Green CAL order 34
# MEDWGK00                            float     No      pixels    median(WLS-ref) [pix], Green SKY order 00
# MEDWGK01                            float     No      pixels    median(WLS-ref) [pix], Green SKY order 01
# MEDWGK02                            float     No      pixels    median(WLS-ref) [pix], Green SKY order 02
# MEDWGK03                            float     No      pixels    median(WLS-ref) [pix], Green SKY order 03
# MEDWGK04                            float     No      pixels    median(WLS-ref) [pix], Green SKY order 04
# MEDWGK05                            float     No      pixels    median(WLS-ref) [pix], Green SKY order 05
# MEDWGK06                            float     No      pixels    median(WLS-ref) [pix], Green SKY order 06
# MEDWGK07                            float     No      pixels    median(WLS-ref) [pix], Green SKY order 07
# MEDWGK08                            float     No      pixels    median(WLS-ref) [pix], Green SKY order 08
# MEDWGK09                            float     No      pixels    median(WLS-ref) [pix], Green SKY order 09
# MEDWGK10                            float     No      pixels    median(WLS-ref) [pix], Green SKY order 10
# MEDWGK11                            float     No      pixels    median(WLS-ref) [pix], Green SKY order 11
# MEDWGK12                            float     No      pixels    median(WLS-ref) [pix], Green SKY order 12
# MEDWGK13                            float     No      pixels    median(WLS-ref) [pix], Green SKY order 13
# MEDWGK14                            float     No      pixels    median(WLS-ref) [pix], Green SKY order 14
# MEDWGK15                            float     No      pixels    median(WLS-ref) [pix], Green SKY order 15
# MEDWGK16                            float     No      pixels    median(WLS-ref) [pix], Green SKY order 16
# MEDWGK17                            float     No      pixels    median(WLS-ref) [pix], Green SKY order 17
# MEDWGK18                            float     No      pixels    median(WLS-ref) [pix], Green SKY order 18
# MEDWGK19                            float     No      pixels    median(WLS-ref) [pix], Green SKY order 19
# MEDWGK20                            float     No      pixels    median(WLS-ref) [pix], Green SKY order 20
# MEDWGK21                            float     No      pixels    median(WLS-ref) [pix], Green SKY order 21
# MEDWGK22                            float     No      pixels    median(WLS-ref) [pix], Green SKY order 22
# MEDWGK23                            float     No      pixels    median(WLS-ref) [pix], Green SKY order 23
# MEDWGK24                            float     No      pixels    median(WLS-ref) [pix], Green SKY order 24
# MEDWGK25                            float     No      pixels    median(WLS-ref) [pix], Green SKY order 25
# MEDWGK26                            float     No      pixels    median(WLS-ref) [pix], Green SKY order 26
# MEDWGK27                            float     No      pixels    median(WLS-ref) [pix], Green SKY order 27
# MEDWGK28                            float     No      pixels    median(WLS-ref) [pix], Green SKY order 28
# MEDWGK29                            float     No      pixels    median(WLS-ref) [pix], Green SKY order 29
# MEDWGK30                            float     No      pixels    median(WLS-ref) [pix], Green SKY order 30
# MEDWGK31                            float     No      pixels    median(WLS-ref) [pix], Green SKY order 31
# MEDWGK32                            float     No      pixels    median(WLS-ref) [pix], Green SKY order 32
# MEDWGK33                            float     No      pixels    median(WLS-ref) [pix], Green SKY order 33
# MEDWGK34                            float     No      pixels    median(WLS-ref) [pix], Green SKY order 34
# MEDWGS00                            float     No      pixels    median(WLS-ref) [pix], Green SCI order 00
# MEDWGS01                            float     No      pixels    median(WLS-ref) [pix], Green SCI order 01
# MEDWGS02                            float     No      pixels    median(WLS-ref) [pix], Green SCI order 02
# ...
# RVS23                               float     No      km/s      RV for SCI order 23
# RVS24                               float     No      km/s      RV for SCI order 24
# RVS25                               float     No      km/s      RV for SCI order 25
# RVS26                               float     No      km/s      RV for SCI order 26
# RVS27                               float     No      km/s      RV for SCI order 27
# RVS28                               float     No      km/s      RV for SCI order 28
# RVS29                               float     No      km/s      RV for SCI order 29
# RVS30                               float     No      km/s      RV for SCI order 30
# RVS31                               float     No      km/s      RV for SCI order 31
# RVS32                               float     No      km/s      RV for SCI order 32
# RVS33                               float     No      km/s      RV for SCI order 33
# RVS34                               float     No      km/s      RV for SCI order 34
# RVS35                               float     No      km/s      RV for SCI order 35
# RVS36                               float     No      km/s      RV for SCI order 36
# RVS37                               float     No      km/s      RV for SCI order 37
# RVS38                               float     No      km/s      RV for SCI order 38
# RVS39                               float     No      km/s      RV for SCI order 39
# RVS40                               float     No      km/s      RV for SCI order 40
# RVS41                               float     No      km/s      RV for SCI order 41
# RVS42                               float     No      km/s      RV for SCI order 42
# RVS43                               float     No      km/s      RV for SCI order 43
# RVS44                               float     No      km/s      RV for SCI order 44
# RVS45                               float     No      km/s      RV for SCI order 45
# RVS46                               float     No      km/s      RV for SCI order 46
# RVS47                               float     No      km/s      RV for SCI order 47
# RVS48                               float     No      km/s      RV for SCI order 48
# RVS49                               float     No      km/s      RV for SCI order 49
# RVS50                               float     No      km/s      RV for SCI order 50
# RVS51                               float     No      km/s      RV for SCI order 51
# RVS52                               float     No      km/s      RV for SCI order 52
# RVS53                               float     No      km/s      RV for SCI order 53
# RVS54                               float     No      km/s      RV for SCI order 54
# RVS55                               float     No      km/s      RV for SCI order 55
# RVS56                               float     No      km/s      RV for SCI order 56
# RVS57                               float     No      km/s      RV for SCI order 57
# RVS58                               float     No      km/s      RV for SCI order 58
# RVS59                               float     No      km/s      RV for SCI order 59
# RVS60                               float     No      km/s      RV for SCI order 60
# RVS61                               float     No      km/s      RV for SCI order 61
# RVS62                               float     No      km/s      RV for SCI order 62
# RVS63                               float     No      km/s      RV for SCI order 63
# RVS64                               float     No      km/s      RV for SCI order 64
# RVS65                               float     No      km/s      RV for SCI order 65
# RVS66                               float     No      km/s      RV for SCI order 66
# RVY00                               float     No      km/s      RV for SKY order 00
# RVY01                               float     No      km/s      RV for SKY order 01
# RVY02                               float     No      km/s      RV for SKY order 02
# RVY03                               float     No      km/s      RV for SKY order 03
# RVY04                               float     No      km/s      RV for SKY order 04
# RVY05                               float     No      km/s      RV for SKY order 05
# RVY06                               float     No      km/s      RV for SKY order 06
# RVY07                               float     No      km/s      RV for SKY order 07
# RVY08                               float     No      km/s      RV for SKY order 08
# RVY09                               float     No      km/s      RV for SKY order 09
# RVY10                               float     No      km/s      RV for SKY order 10
# RVY11                               float     No      km/s      RV for SKY order 11
# RVY12                               float     No      km/s      RV for SKY order 12
# RVY13                               float     No      km/s      RV for SKY order 13
# RVY14                               float     No      km/s      RV for SKY order 14
# RVY15                               float     No      km/s      RV for SKY order 15
# RVY16                               float     No      km/s      RV for SKY order 16
# RVY17                               float     No      km/s      RV for SKY order 17
# RVY18                               float     No      km/s      RV for SKY order 18
# RVY19                               float     No      km/s      RV for SKY order 19
# RVY20                               float     No      km/s      RV for SKY order 20
# RVY21                               float     No      km/s      RV for SKY order 21
# RVY22                               float     No      km/s      RV for SKY order 22
# RVY23                               float     No      km/s      RV for SKY order 23
# RVY24                               float     No      km/s      RV for SKY order 24
# RVY25                               float     No      km/s      RV for SKY order 25
# RVY26                               float     No      km/s      RV for SKY order 26
# RVY27                               float     No      km/s      RV for SKY order 27
# RVY28                               float     No      km/s      RV for SKY order 28
# RVY29                               float     No      km/s      RV for SKY order 29
# RVY30                               float     No      km/s      RV for SKY order 30
# RVY31                               float     No      km/s      RV for SKY order 31
# RVY32                               float     No      km/s      RV for SKY order 32
# RVY33                               float     No      km/s      RV for SKY order 33
# RVY34                               float     No      km/s      RV for SKY order 34
# RVY35                               float     No      km/s      RV for SKY order 35
# RVY36                               float     No      km/s      RV for SKY order 36
# RVY37                               float     No      km/s      RV for SKY order 37
# RVY38                               float     No      km/s      RV for SKY order 38
# RVY39                               float     No      km/s      RV for SKY order 39
# RVY40                               float     No      km/s      RV for SKY order 40
# RVY41                               float     No      km/s      RV for SKY order 41
# RVY42                               float     No      km/s      RV for SKY order 42
# RVY43                               float     No      km/s      RV for SKY order 43
# RVY44                               float     No      km/s      RV for SKY order 44
# RVY45                               float     No      km/s      RV for SKY order 45
# RVY46                               float     No      km/s      RV for SKY order 46
# RVY47                               float     No      km/s      RV for SKY order 47
# RVY48                               float     No      km/s      RV for SKY order 48
# RVY49                               float     No      km/s      RV for SKY order 49
# RVY50                               float     No      km/s      RV for SKY order 50
# RVY51                               float     No      km/s      RV for SKY order 51
# RVY52                               float     No      km/s      RV for SKY order 52
# RVY53                               float     No      km/s      RV for SKY order 53
# RVY54                               float     No      km/s      RV for SKY order 54
# RVY55                               float     No      km/s      RV for SKY order 55
# RVY56                               float     No      km/s      RV for SKY order 56
# RVY57                               float     No      km/s      RV for SKY order 57
# RVY58                               float     No      km/s      RV for SKY order 58
# RVY59                               float     No      km/s      RV for SKY order 59
# RVY60                               float     No      km/s      RV for SKY order 60
# RVY61                               float     No      km/s      RV for SKY order 61
# RVY62                               float     No      km/s      RV for SKY order 62
# RVY63                               float     No      km/s      RV for SKY order 63
# RVY64                               float     No      km/s      RV for SKY order 64
# RVY65                               float     No      km/s      RV for SKY order 65
# RVY66                               float     No      km/s      RV for SKY order 66
#
# L2 CCF Header:
# --------------------------------------------------------------------------------------------------------------------------------
# Keyword                             Datatype  Indexed Units     Description
# --------------------------------------------------------------------------------------------------------------------------------
# CALMPATH                            string    No                Mask path for CAL
# CAL_MASK                            string    No                Mask name for CAL
# SCIMPATH                            string    No                Mask path for SCI
# SCI_MASK                            string    No                Mask name for SCI
# SKYMPATH                            string    No                Mask path for SKY
# SKY_MASK                            string    No                Mask name for SKY
